# %%
# !pip install scikit-image

# %%
from skimage.io import imread , imsave , imshow
import matplotlib.pyplot as plt

# %%
img_dog = imread(r"C:\Users\User\Pictures\Screenshots\Screenshot 2026-06-20 213838.png")
img_dog
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[143, 143, 143, 255],
#         [143, 143, 143, 255],
#         [142, 142, 142, 255],
#         ...,
#         [102, 102, 102, 255],
#         [102, 102, 102, 255],
#         [101, 101, 101, 255]],
#
#        [[143, 143, 143, 255],
#         [143, 143, 143, 255],
#         [143, 143, 143, 255],
#         ...,
#         [103, 103, 103, 255],
# ...

# %%
type(img_dog)
# Out:
# numpy.ndarray

# %%
img_dog.shape
# Out:
# (380, 412, 4)

# %%
img_dog.size
# Out:
# 626240

# %%
imshow(img_dog)
plt.show()

# %%
plt.figure(figsize=(12 , 40))
imshow(img_dog)
plt.title("dog")
#plt.axis("off")
plt.show()

# %%
img_dog[350 , 100]
# Out:
# array([161, 161, 161, 255], dtype=uint8)

# %%
img_dog[300 , 400]
# Out:
# array([123, 123, 123, 255], dtype=uint8)

# %%
img_rabbit = imread(r"C:\Users\User\Pictures\Screenshots\Screenshot 2026-06-20 203240.png")
img_rabbit
# Out:
# array([[[ 48,  67,  75, 255],
#         [ 48,  67,  74, 255],
#         [ 48,  67,  74, 255],
#         ...,
#         [ 84, 101, 119, 255],
#         [ 84, 101, 119, 255],
#         [ 85, 102, 119, 255]],
#
#        [[ 48,  67,  74, 255],
#         [ 48,  67,  74, 255],
#         [ 48,  67,  74, 255],
#         ...,
#         [ 85, 102, 119, 255],
#         [ 85, 102, 120, 255],
#         [ 86, 102, 120, 255]],
#
#        [[ 48,  67,  74, 255],
#         [ 48,  66,  74, 255],
#         [ 47,  66,  74, 255],
#         ...,
#         [ 86, 102, 120, 255],
#         [ 86, 103, 121, 255],
#         [ 87, 103, 121, 255]],
#
#        ...,
#
#        [[ 47,  50,  38, 255],
#         [ 36,  40,  31, 255],
#         [ 28,  32,  25, 255],
#         ...,
#         [ 16,  20,  19, 255],
#         [ 17,  22,  20, 255],
#         [ 18,  22,  22, 255]],
#
#        [[ 49,  51,  41, 255],
#         [ 40,  44,  36, 255],
#         [ 35,  38,  31, 255],
#         ...,
#         [ 15,  19,  18, 255],
# ...

# %%
img_rabbit.shape
# Out:
# (568, 576, 4)

# %%
imshow(img_rabbit)

# %%
img_rabbit[0,200]
# Out:
# array([ 26,  30,  33, 255], dtype=uint8)

# %%
img_rabbit[300 , 0]
# Out:
# array([ 28,  30,  27, 255], dtype=uint8)

# %%
imshow(img_rabbit[:,:,0])

# %%
imshow(img_rabbit[:,:,1])

# %%
imshow(img_rabbit[:,:,2])
